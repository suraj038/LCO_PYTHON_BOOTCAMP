# %%
import io
import matplotlib.pyplot as plt
import cv2 as cv
from PIL import Image
import requests
import numpy as np
from pylab import rcParams
rcParams['figure.figsize']=10,10

# %%
image=Image.open(io.BytesIO(requests.get("https://c1.staticflickr.com/9/8278/15606491429_aa5b5cf179_b.jpg",stream=True).content))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
plt.imshow(image)

# %%
image.save("ft.jpg")

# %%
image.size
# Out:
# (982, 1024)

# %%
image = cv.imread('D:/images/doraemon.png')

# %%
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
cv.imshow('Original image',image)
cv.imshow('Gray image', gray)

# %%
black=np.ones((100,100),dtype=np.uint8)

# %%
plt.imshow(black,cmap='gray')

# %%
white=np.ones([100,100,3],dtype=np.uint8)*255

# %%
plt.imshow(white,cmap='gray')

# %%
white.shape
# Out:
# (100, 100, 3)

# %%
cv.cvtColor(white,cv.COLOR_RGB2GRAY)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
black1=black.copy()

# %%
we=cv.line(black1,(0,40),(100,40),(200,100,0),5)

# %%
plt.imshow(we)

# %%
black3 = black.copy()
black4 = cv.rectangle(black3,(25,25),(75,75),(200,0,2),2)
black5 = cv.rectangle(black4,(0,0),(25,25),(2,2),10)
plt.imshow(black5)
